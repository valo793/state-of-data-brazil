# %% [markdown]
# # 02. Validação e Qualidade da Camada Silver
#
# Auditoria dos dados limpos, harmonizados e tipados na Camada Silver (`state_of_data_silver.parquet`).

# %%
import pandas as pd
from pathlib import Path

silver_path = Path("../data/processed/silver/state_of_data_silver.parquet")
df_silver = pd.read_parquet(silver_path)
print(f"Total de registros na Camada Silver: {len(df_silver)}")
print(f"Total de colunas estruturadas: {len(df_silver.columns)}")
df_silver.head(3)
# Out:
# Total de registros na Camada Silver: 14002
# Total de colunas estruturadas: 47
#                      id_respondente  idade  ... satisfeito_empresa_bool ano_pesquisa
# 0  001b2d1qtli8t9z7oqgdhj001b2d4i0g     31  ...                   False    2023-2024
# 1  0026aa3fwd78u0026asg7456tfkjg2cs     30  ...                    True    2023-2024
# 2  00r21rb9pusd1b0v7ew00r21rw3dy69w     37  ...                    True    2023-2024
#
# [3 rows x 47 columns]

# %% [markdown]
# ## 1. Verificação de Chaves Primárias e Deduplicação

# %%
print("Contagem por edição:")
print(df_silver["ano_pesquisa"].value_counts())

null_ids = df_silver["id_respondente"].isna().sum()
dups = df_silver.duplicated(subset=["ano_pesquisa", "id_respondente"]).sum()
print(f"\nIDs nulos: {null_ids}")
print(f"Duplicidades exatas: {dups}")
# Out:
# Contagem por edição:
# ano_pesquisa
# 2023-2024    5293
# 2024-2025    5215
# 2025-2026    3494
# Name: count, dtype: int64
#
# IDs nulos: 0
# Duplicidades exatas: 0

# %% [markdown]
# ## 2. Validação dos Campos Calculados e Tipados

# %%
print("Resumo estatístico do salário médio estimado (R$):")
print(df_silver["salario_medio_estimado"].describe())
# Out:
# Resumo estatístico do salário médio estimado (R$):
# count    12841.000000
# mean     11828.878763
# std       9262.397259
# min        500.000000
# 25%       5000.500000
# 50%      10000.500000
# 75%      14000.500000
# max      48001.200000
# Name: salario_medio_estimado, dtype: float64
